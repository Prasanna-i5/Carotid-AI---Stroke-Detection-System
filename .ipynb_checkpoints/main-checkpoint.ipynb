# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from tqdm import tqdm

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
import os
import cv2
import numpy as np
from tqdm import tqdm

class_names = ["Normal", "Stroker"]
class_names_label = {class_name: i for i, class_name in enumerate(class_names)}

IMAGE_SIZE = (64, 64)

def load_data():
    datasets = ['train', 'test']
    output = []

    for dataset in datasets:
        images = []
        labels = []

        print(f"Loading {dataset}...")

        # Iterate through D-I, D-II, D-III
        for subset in os.listdir(dataset):
            subset_path = os.path.join(dataset, subset)

            # Iterate through each class folder inside D-I/D-II/D-III
            for folder in os.listdir(subset_path):
                label = class_names_label[folder]
                folder_path = os.path.join(subset_path, folder)

                for file in tqdm(os.listdir(folder_path)):
                    img_path = os.path.join(folder_path, file)
                    image = cv2.imread(img_path)
                    if image is None:
                        continue
                    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                    image = cv2.resize(image, IMAGE_SIZE)
                    images.append(image)
                    labels.append(label)

        images = np.array(images, dtype='float32')
        labels = np.array(labels, dtype='int32')
        output.append((images, labels))

    return output

(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading train...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1500/1500 [00:02<00:00, 531.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1500/1500 [00:03<00:00, 423.57it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1600/1600 [00:03<00:00, 471.58it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 4019/4019 [00:11<00:00, 362.45it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 98/98 [00:00<00:00, 314.90it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 155/155 [00:00<00:00, 355.64it/s]
# Loading test...
# 100%|███████████████████████████████████████████████████████████████████████████████| 371/371 [00:00<00:00, 541.16it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 363/363 [00:01<00:00, 356.21it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 279/279 [00:00<00:00, 473.29it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 83/83 [00:00<00:00, 346.78it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 98/98 [00:00<00:00, 207.18it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 155/155 [00:00<00:00, 363.35it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=25)

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 8872
# Number of testing examples: 1349
# Each image is of size: (64, 64)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
pd.DataFrame({'train': train_counts,
                    'test': test_counts},
             index=class_names
            ).plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0,0) ,
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ## Good practice: scale the data

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ## Visualize the data
# We can display a random image from the training set.

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """

    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %%
import matplotlib.pyplot as plt

def display_examples(class_names, images, labels):
    """
    Display 25 images from the images array with its corresponding labels
    """
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # CNN

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (64, 64, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(2, activation=tf.nn.softmax)
])
# Out:
# C:\Users\HP\anaconda3\envs\currency\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 28s 475ms/step - accuracy: 0.6965 - loss: 0.6354 - val_accuracy: 0.8772 - val_loss: 0.2984
# Epoch 2/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 39s 442ms/step - accuracy: 0.8916 - loss: 0.2710 - val_accuracy: 0.9262 - val_loss: 0.2168
# Epoch 3/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 31s 553ms/step - accuracy: 0.9371 - loss: 0.1704 - val_accuracy: 0.9577 - val_loss: 0.1279
# Epoch 4/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 28s 499ms/step - accuracy: 0.9675 - loss: 0.1104 - val_accuracy: 0.9645 - val_loss: 0.1109
# Epoch 5/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 40s 473ms/step - accuracy: 0.9825 - loss: 0.0695 - val_accuracy: 0.9735 - val_loss: 0.0955
# Epoch 6/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 28s 493ms/step - accuracy: 0.9906 - loss: 0.0483 - val_accuracy: 0.9713 - val_loss: 0.0872
# Epoch 7/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 28s 505ms/step - accuracy: 0.9917 - loss: 0.0378 - val_accuracy: 0.9854 - val_loss: 0.0584
# Epoch 8/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 24s 435ms/step - accuracy: 0.9981 - loss: 0.0130 - val_accuracy: 0.9882 - val_loss: 0.0483
# Epoch 9/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 407ms/step - accuracy: 0.9992 - loss: 0.0076 - val_accuracy: 0.9882 - val_loss: 0.0484
# Epoch 10/10
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 23s 405ms/step - accuracy: 0.9999 - loss: 0.0041 - val_accuracy: 0.9870 - val_loss: 0.0602

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle("CNN Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  # adjust so title fits
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9935 - loss: 0.0306
# Test Accuracy: 0.9881

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       601
#            1       1.00      0.98      0.99       748
#
#     accuracy                           0.99      1349
#    macro avg       0.99      0.99      0.99      1349
# weighted avg       0.99      0.99      0.99      1349

# %% [markdown]
# # **DenseNet169**

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# Load DenseNet169 without the top classification layer
base_model = DenseNet169(weights='imagenet', include_top=False, input_shape=(64, 64, 3))

# Freeze the base model
base_model.trainable = False

# Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(train_images, train_labels, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 90s 328ms/step - accuracy: 0.8472 - loss: 0.3845 - val_accuracy: 0.9561 - val_loss: 0.1245
# Epoch 2/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 63s 285ms/step - accuracy: 0.9626 - loss: 0.1061 - val_accuracy: 0.9606 - val_loss: 0.1102
# Epoch 3/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ -1794s -8118522us/step - accuracy: 0.9764 - loss: 0.0676 - val_accuracy: 0.9718 - val_loss: 0.0900
# Epoch 4/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 65s 293ms/step - accuracy: 0.9884 - loss: 0.0419 - val_accuracy: 0.9820 - val_loss: 0.0700
# Epoch 5/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 60s 271ms/step - accuracy: 0.9959 - loss: 0.0214 - val_accuracy: 0.9769 - val_loss: 0.0843
# Epoch 6/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 64s 290ms/step - accuracy: 0.9928 - loss: 0.0208 - val_accuracy: 0.9814 - val_loss: 0.0671
# Epoch 7/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 66s 299ms/step - accuracy: 0.9962 - loss: 0.0147 - val_accuracy: 0.9769 - val_loss: 0.0807
# Epoch 8/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 59s 265ms/step - accuracy: 0.9976 - loss: 0.0108 - val_accuracy: 0.9837 - val_loss: 0.0588
# Epoch 9/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 59s 264ms/step - accuracy: 0.9967 - loss: 0.0126 - val_accuracy: 0.9848 - val_loss: 0.0614
# Epoch 10/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 59s 264ms/step - accuracy: 0.9961 - loss: 0.0115 - val_accuracy: 0.9837 - val_loss: 0.0689

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle(" DenseNet169 Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy: {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - accuracy: 0.9937 - loss: 0.0344
# Test Accuracy: 0.9874

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 20s 354ms/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       601
#            1       1.00      0.98      0.99       748
#
#     accuracy                           0.99      1349
#    macro avg       0.99      0.99      0.99      1349
# weighted avg       0.99      0.99      0.99      1349

# %% [markdown]
# # **ResNet101**

# %%
from tensorflow.keras.applications import ResNet101

base_model = ResNet101(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 149s 615ms/step - accuracy: 0.6744 - loss: 0.6055 - val_accuracy: 0.7904 - val_loss: 0.5069
# Epoch 2/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 129s 580ms/step - accuracy: 0.7777 - loss: 0.4705 - val_accuracy: 0.8113 - val_loss: 0.4261
# Epoch 3/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 132s 595ms/step - accuracy: 0.7909 - loss: 0.4381 - val_accuracy: 0.8034 - val_loss: 0.4089
# Epoch 4/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 129s 580ms/step - accuracy: 0.8247 - loss: 0.3887 - val_accuracy: 0.8372 - val_loss: 0.3765
# Epoch 5/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 125s 564ms/step - accuracy: 0.8317 - loss: 0.3751 - val_accuracy: 0.8479 - val_loss: 0.3588
# Epoch 6/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 123s 556ms/step - accuracy: 0.8417 - loss: 0.3507 - val_accuracy: 0.8445 - val_loss: 0.3562
# Epoch 7/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 121s 545ms/step - accuracy: 0.8333 - loss: 0.3541 - val_accuracy: 0.8485 - val_loss: 0.3499
# Epoch 8/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 127s 573ms/step - accuracy: 0.8514 - loss: 0.3326 - val_accuracy: 0.8214 - val_loss: 0.3952
# Epoch 9/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 150s 609ms/step - accuracy: 0.8409 - loss: 0.3463 - val_accuracy: 0.8485 - val_loss: 0.3343
# Epoch 10/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 139s 625ms/step - accuracy: 0.8615 - loss: 0.3048 - val_accuracy: 0.8485 - val_loss: 0.3466

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle(" ResNet101 Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy : {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 20s 463ms/step - accuracy: 0.8168 - loss: 0.3804
# Test Accuracy : 0.7813

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 28s 567ms/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.67      0.73       601
#            1       0.77      0.87      0.82       748
#
#     accuracy                           0.78      1349
#    macro avg       0.79      0.77      0.77      1349
# weighted avg       0.78      0.78      0.78      1349

# %% [markdown]
# # **VGG19**

# %%
from tensorflow.keras.applications import VGG19

base_model = VGG19(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 517s 2s/step - accuracy: 0.7463 - loss: 0.4928 - val_accuracy: 0.8761 - val_loss: 0.3101
# Epoch 2/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 495s 2s/step - accuracy: 0.8790 - loss: 0.2896 - val_accuracy: 0.8501 - val_loss: 0.3393
# Epoch 3/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 473s 2s/step - accuracy: 0.8974 - loss: 0.2499 - val_accuracy: 0.9177 - val_loss: 0.2137
# Epoch 4/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.9241 - loss: 0.2029 - val_accuracy: 0.9206 - val_loss: 0.1978
# Epoch 5/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.9346 - loss: 0.1752 - val_accuracy: 0.9414 - val_loss: 0.1710
# Epoch 6/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 497s 2s/step - accuracy: 0.9451 - loss: 0.1555 - val_accuracy: 0.9431 - val_loss: 0.1519
# Epoch 7/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 536s 2s/step - accuracy: 0.9536 - loss: 0.1299 - val_accuracy: 0.9454 - val_loss: 0.1398
# Epoch 8/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 499s 2s/step - accuracy: 0.9544 - loss: 0.1271 - val_accuracy: 0.9487 - val_loss: 0.1360
# Epoch 9/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.9595 - loss: 0.1139 - val_accuracy: 0.9611 - val_loss: 0.1197
# Epoch 10/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.9643 - loss: 0.1017 - val_accuracy: 0.9589 - val_loss: 0.1151

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle(" VGG 19 Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy : {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - accuracy: 0.9729 - loss: 0.1095
# Test Accuracy : 0.9615

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96       601
#            1       0.95      0.99      0.97       748
#
#     accuracy                           0.96      1349
#    macro avg       0.96      0.96      0.96      1349
# weighted avg       0.96      0.96      0.96      1349

# %% [markdown]
# # **MobileNetV3**

# %%
from tensorflow.keras.applications import MobileNetV3Small


base_model = MobileNetV3Small(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# C:\Users\HP\anaconda3\envs\currency\lib\site-packages\keras\src\applications\mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Epoch 1/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 20s 41ms/step - accuracy: 0.6266 - loss: 0.6723 - val_accuracy: 0.6670 - val_loss: 0.6009
# Epoch 2/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.6874 - loss: 0.6063 - val_accuracy: 0.7228 - val_loss: 0.5706
# Epoch 3/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.6955 - loss: 0.5925 - val_accuracy: 0.7358 - val_loss: 0.5535
# Epoch 4/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.7189 - loss: 0.5715 - val_accuracy: 0.7161 - val_loss: 0.5425
# Epoch 5/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.7201 - loss: 0.5622 - val_accuracy: 0.7380 - val_loss: 0.5298
# Epoch 6/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.7240 - loss: 0.5577 - val_accuracy: 0.7499 - val_loss: 0.5216
# Epoch 7/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.7463 - loss: 0.5380 - val_accuracy: 0.7442 - val_loss: 0.5076
# Epoch 8/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.7313 - loss: 0.5431 - val_accuracy: 0.7786 - val_loss: 0.5300
# Epoch 9/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.7456 - loss: 0.5349 - val_accuracy: 0.7346 - val_loss: 0.5088
# Epoch 10/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - accuracy: 0.7527 - loss: 0.5132 - val_accuracy: 0.7938 - val_loss: 0.5205

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle(" MobileNetV3 Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy : {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7159 - loss: 0.5692
# Test Accuracy : 0.7057

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.68      0.67       601
#            1       0.74      0.72      0.73       748
#
#     accuracy                           0.71      1349
#    macro avg       0.70      0.70      0.70      1349
# weighted avg       0.71      0.71      0.71      1349

# %% [markdown]
# # **AlexNet**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(96, (11,11), strides=4, activation='relu', input_shape=(64,64,3)),
    MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    Conv2D(256, (5,5), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    Conv2D(384, (3,3), padding='same', activation='relu'),
    Conv2D(384, (3,3), padding='same', activation='relu'),
    Conv2D(256, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(3,3), strides=(2,2), padding='same'),
    Flatten(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_images, train_labels, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# C:\Users\HP\anaconda3\envs\currency\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 82s 358ms/step - accuracy: 0.6194 - loss: 0.6948 - val_accuracy: 0.7003 - val_loss: 0.5976
# Epoch 2/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 82s 368ms/step - accuracy: 0.6906 - loss: 0.6142 - val_accuracy: 0.7104 - val_loss: 0.6028
# Epoch 3/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 77s 348ms/step - accuracy: 0.7014 - loss: 0.5535 - val_accuracy: 0.7899 - val_loss: 0.4469
# Epoch 4/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 84s 359ms/step - accuracy: 0.7983 - loss: 0.4286 - val_accuracy: 0.8130 - val_loss: 0.3924
# Epoch 5/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 97s 436ms/step - accuracy: 0.8415 - loss: 0.3367 - val_accuracy: 0.8755 - val_loss: 0.2781
# Epoch 6/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 89s 402ms/step - accuracy: 0.8713 - loss: 0.2693 - val_accuracy: 0.9127 - val_loss: 0.2281
# Epoch 7/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 75s 340ms/step - accuracy: 0.9164 - loss: 0.2034 - val_accuracy: 0.9070 - val_loss: 0.2833
# Epoch 8/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 75s 337ms/step - accuracy: 0.9196 - loss: 0.1809 - val_accuracy: 0.9285 - val_loss: 0.1975
# Epoch 9/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 88s 397ms/step - accuracy: 0.9261 - loss: 0.1590 - val_accuracy: 0.9341 - val_loss: 0.1809
# Epoch 10/10
# 222/222 ━━━━━━━━━━━━━━━━━━━━ 77s 345ms/step - accuracy: 0.9291 - loss: 0.1607 - val_accuracy: 0.9448 - val_loss: 0.1988

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score
import numpy as np

# %%
fig, axs = plt.subplots(2, 1, figsize=(6,10))

# Accuracy plot
axs[0].plot(history.history['accuracy'], label='Training Accuracy')
axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Model Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Loss plot
axs[1].plot(history.history['loss'], label='Training Loss')
axs[1].plot(history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Model Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()


fig.suptitle(" ResNet101 Training & Validation Performance", fontsize=16, fontweight="bold")

plt.tight_layout(rect=[0, 0, 1, 0.96])  
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test Accuracy : {test_acc:.4f}')
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9132 - loss: 0.2012
# Test Accuracy : 0.9103

# %%
y_pred_probs = model.predict(test_images)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_labels
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step

# %%
TP = cm[1,1]
TN = cm[0,0]
FP = cm[0,1]
FN = cm[1,0]

sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)
precision = TP / (TP + FP)
f1 = 2 * (precision * sensitivity) / (precision + sensitivity)

print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.9813
# Specificity: 0.9967
# Precision: 0.9973
# F1 Score: 0.9892

# %%
CM = confusion_matrix(test_labels, y_pred)
ax = plt.axes()
sn.heatmap(CM, annot=True,
           annot_kws={"size": 10},
           xticklabels=class_names,
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %%
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       601
#            1       0.93      0.90      0.92       748
#
#     accuracy                           0.91      1349
#    macro avg       0.91      0.91      0.91      1349
# weighted avg       0.91      0.91      0.91      1349

# %% [markdown]
# # **saved pre-trained model**

# %%
model.save_weights("model_dense.weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
model_json=model.to_json()
with open("model_dense.json", "w") as json_file:
    json_file.write(model_json)
